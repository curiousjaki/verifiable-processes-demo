# %%
import pm4py

process_tree = pm4py.read_bpmn('../media/petri-net-test1.bpmn')

# %%
net, im, fm = pm4py.convert_to_petri_net(process_tree)

# %%
pm4py.view_petri_net(net, im, fm, format='png')

# %%
net
# Out:
# places: [ ent_Event_1slzrob, ent_Gateway_1p8p55z, exi_Gateway_06ae8ji, sink, source ]
# transitions: [ (Activity_13a4cd2, 'Prove'), (Activity_15ldp0t, 'Verify'), (Activity_1o8qqwi, 'A'), (Activity_1rv98p4, 'B'), (Event_1slzrob, None) ]
# arcs: [ (Activity_13a4cd2, 'Prove')->exi_Gateway_06ae8ji, (Activity_15ldp0t, 'Verify')->sink, (Activity_1o8qqwi, 'A')->ent_Gateway_1p8p55z, (Activity_1rv98p4, 'B')->ent_Gateway_1p8p55z, (Event_1slzrob, None)->sink, ent_Event_1slzrob->(Event_1slzrob, None), ent_Gateway_1p8p55z->(Activity_15ldp0t, 'Verify'), exi_Gateway_06ae8ji->(Activity_1o8qqwi, 'A'), exi_Gateway_06ae8ji->(Activity_1rv98p4, 'B'), source->(Activity_13a4cd2, 'Prove') ]
